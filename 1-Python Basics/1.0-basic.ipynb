# %% [markdown]
# Syntax refers to the set of rules that defines the combinations of symbols that are considered to be correctly structured programs in a language. In simpler terms, syntax is about the correct arrangement of the words and symbols in a code.
#
#
# Semantics refers to the meaning or the interpretation of the symbols, characters, and commands in a language. it is about what the code is supposed to do when it runs.

# %%
## Basic Syntax Rules In Python
## Case Sensitivity- Python is case-sensitive, which means that it treats uppercase and lowercase letters as distinct. For example, the variable names "Variable", "variable", and "VARIABLE" would be considered different variables.

name  = "Mohamed"
Name  = "Data Engineer"

print(name)  # Output: Mohamed
print(Name)  # Output: Data Engineer
# Out:
# Mohamed
# Data Engineer

# %% [markdown]
# ## Indentation
#
# ### Indentation- Python uses indentation (whitespace at the beginning of a line) to define the structure and scope of code blocks, such as loops, functions, and conditionals. Proper indentation is crucial for the correct execution of the code.

# %%
age=32
if age >= 18:
    print(f"your age is {age},  You are an adult.")
# Out:
# your age is 32,  You are an adult.

# %%
## Line Continuation
## Line Continuation- In Python, if a statement is too long to fit on a single line, you can use a backslash (\) to indicate that the statement continues on the next line.
total = 1 + 2 + 3 + \
        4 + 5 + 6 + \
        7 + 8 + 9
print(total)  # Output: 45
# Out:
# 45

# %%
## Multiple Statements on a Single Line
## Multiple Statements on a Single Line- You can write multiple statements on a single line by separating them with a semicolon (;).
x = 10; y = 20; z = x + y
print(z)  # Output: 30
# Out:
# 30

# %%
## Understand Semantcs In Python
# variable assignment
x = 10  # assigns the value 10 to the variable x
name = "Alice"  # assigns the string "Alice" to the variable name
type_of_x = type(x)  # gets the type of the variable x, which is int
type_of_name = type(name)  # gets the type of the variable name, which is str
print(f"x: {x}, type: {type_of_x}")  # Output: x: 10, type: <class 'int'>
print(f"name: {name}, type: {type_of_name}")  # Output: name: Alice, type: <class 'str'>
# Out:
# x: 10, type: <class 'int'>
# name: Alice, type: <class 'str'>

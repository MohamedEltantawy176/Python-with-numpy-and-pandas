# %% [markdown]
# ## Filepath

# %%
## create a new directory
import os
new_directory = "package"
os.makedirs(new_directory)
print(f"Directory '{new_directory}' created.")
# Out:
# Directory 'package' created.

# %%
## List files in a directories
items = os.listdir('.')
print(items)
# Out:
# ['destination.txt', '6.1-fileoperation.ipynb', 'example.bin', 'example.txt', '6.2-filepath.ipynb', 'package']

# %%
### Joining paths

dir_name = "folder"
file_name = "file.txt"
full_path = os.path.join(dir_name, file_name)
print(full_path)  # Output: folder/file.txt or folder\file.txt depending on OS
# Out:
# folder/file.txt

# %%
dir_name = "folder"
file_name = "file.txt"
full_path = os.path.join(os.getcwd(),dir_name, file_name)
print(full_path)  # Output: folder/file.txt or folder\file.txt depending on OS
# Out:
# /Users/mohamed/Desktop/Mohamed-Dev/Data-engineering/python/6-File Handling/folder/file.txt

# %%
path="example1.txt"
if os.path.exists(path):
    print(f"The file at {path} exists.")
else:
    print(f"The file at {path} does not exist.")
# Out:
# The file at example1.txt does not exist.

# %%
# check if a Path is a file or directory
path = "example.txt"
if os.path.isfile(path):
    print(f"{path} is a file.")
elif os.path.isdir(path):
    print(f"{path} is a directory.")
else:
    print(f"{path} does not exist.")
# Out:
# example.txt is a file.

# %%
## Getting absolute path
relative_path = "example.txt"
absolute_path = os.path.abspath(relative_path)
print(f"Absolute path: {absolute_path}")
# Out:
# Absolute path: /Users/mohamed/Desktop/Mohamed-Dev/Data-engineering/python/6-File Handling/example.txt
